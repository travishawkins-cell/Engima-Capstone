# %% [markdown]
# ## Simple pdf loader and output generator

# %%
import numpy as np

# Dictionary to map digits to their spelled-out forms
digit_map = {
    '0': 'zero', '1': 'one', '2': 'two', '3': 'three', '4': 'four',
    '5': 'five', '6': 'six', '7': 'seven', '8': 'eight', '9': 'nine'
}

# Load the text file
with open('bee movie script.txt', 'r') as file:
    text = file.read()

# Replace all digit characters with their spelled-out forms
processed_text = ''
for char in text:
    if char.isdigit():
        processed_text += digit_map[char]
    else:
        processed_text += char

# Create a list of all characters
char_list = list(processed_text)

# Convert to numpy matrix with 1 column
matrix = np.array(char_list).reshape(-1, 1)

# Display the matrix
print("Matrix shape:", matrix.shape)
print("\nFirst 20 rows of the matrix:")
print(matrix[:20])

# Optional: Save the matrix
np.savetxt('output_matrix.txt', matrix, fmt='%s', delimiter='')
# Out:
# Matrix shape: (49647, 1)
#
# First 20 rows of the matrix:
# [['A']
#  ['c']
#  ['c']
#  ['o']
#  ['r']
#  ['d']
#  ['i']
#  ['n']
#  ['g']
#  [' ']
#  ['t']
#  ['o']
#  [' ']
#  ['a']
#  ['l']
#  ['l']
#  [' ']
#  ['k']
#  ['n']
#  ['o']]

# %%
print(char_list)
# Out:
# ['A', 'c', 'c', 'o', 'r', 'd', 'i', 'n', 'g', ' ', 't', 'o', ' ', 'a', 'l', 'l', ' ', 'k', 'n', 'o', 'w', 'n', ' ', 'l', 'a', 'w', 's', ' ', 'o', 'f', ' ', 'a', 'v', 'i', 'a', 't', 'i', 'o', 'n', ',', ' ', 't', 'h', 'e', 'r', 'e', ' ', 'i', 's', ' ', 'n', 'o', ' ', 'w', 'a', 'y', ' ', 'a', ' ', 'b', 'e', 'e', ' ', 's', 'h', 'o', 'u', 'l', 'd', ' ', 'b', 'e', ' ', 'a', 'b', 'l', 'e', ' ', 't', 'o', ' ', 'f', 'l', 'y', '.', '\n', 'I', 't', 's', ' ', 'w', 'i', 'n', 'g', 's', ' ', 'a', 'r', 'e', ' ', 't', 'o', 'o', ' ', 's', 'm', 'a', 'l', 'l', ' ', 't', 'o', ' ', 'g', 'e', 't', ' ', 'i', 't', 's', ' ', 'f', 'a', 't', ' ', 'l', 'i', 't', 't', 'l', 'e', ' ', 'b', 'o', 'd', 'y', ' ', 'o', 'f', 'f', ' ', 't', 'h', 'e', ' ', 'g', 'r', 'o', 'u', 'n', 'd', '.', '\n', 'T', 'h', 'e', ' ', 'b', 'e', 'e', ',', ' ', 'o', 'f', ' ', 'c', 'o', 'u', 'r', 's', 'e', ',', ' ', 'f', 'l', 'i', 'e', 's', ' ', 'a', 'n', 'y', 'w', 'a', 'y', ' ', 'b', 'e', 'c', 'a', 'u', 's', 'e', ' ', 'b', 'e', 'e', 's', ' ', 'd', 'o', 'n', "'", 't', ' ', 'c', 'a', 'r', 'e', ' ', 'w', 'h', 'a', 't', ' ', 'h', 'u', 'm', 'a', 'n', 's', ' ', 't', 'h', 'i', 'n', 'k', ' ', 'i', 's', ' ', 'i', 'm', 'p', 'o', 's', 's', 'i', 'b', 'l', 'e', '.', '\n', 'Y', 'e', 'l', 'l', 'o', 'w', ',', ' ', 'b', 'l', 'a', 'c', 'k', '.', ' ', 'Y', 'e', 'l', 'l', 'o', 'w', ',', ' ', 'b', 'l', 'a', 'c', 'k', '.', ' ', 'Y', 'e', 'l', 'l', 'o', 'w', ',', ' ', 'b', 'l', 'a', 'c', 'k', '.', ' ', 'Y', 'e', 'l', 'l', 'o', 'w', ',', ' ', 'b', 'l', 'a', 'c', 'k', '.', '\n', 'O', 'o', 'h', ',', ' ', 'b', 'l', 'a', 'c', 'k', ' ', 'a', 'n', 'd', ' ', 'y', 'e', 'l', 'l', 'o', 'w', '!', '\n', 'L', 'e', 't', "'", 's', ' ', 's', 'h', 'a', 'k', 'e', ' ', 'i', 't', ' ', 'u', 'p', ' ', 'a', ' ', 'l', 'i', 't', 't', 'l', 'e', '.', '\n', 'B', 'a', 'r', 'r', 'y', '!', ' ', 'B', 'r', 'e', 'a', 'k', 'f', 'a', 's', 't', ' ', 'i', 's', ' ', 'r', 'e', 'a', 'd', 'y', '!', '\n', 'C', 'o', 'm', 'i', 'n', 'g', '!', '\n', 'H', 'a', 'n', 'g', ' ', 'o', 'n', ' ', 'a', ' ', 's', 'e', 'c', 'o', 'n', 'd', '.', '\n', 'H', 'e', 'l', 'l', 'o', '?', '\n', 'B', 'a', 'r', 'r', 'y', '?', '\n', 'A', 'd', 'a', 'm', '?', '\n', 'C', 'a', 'n', ' ', 'y', 'o', 'u', ' ', 'b', 'e', 'l', 'i', 'e', 'v', 'e', ' ', 't', 'h', 'i', 's', ' ', 'i', 's', ' ', 'h', 'a', 'p', 'p', 'e', 'n', 'i', 'n', 'g', '?', '\n', 'I', ' ', 'c', 'a', 'n', "'", 't', '.', '\n', 'I', "'", 'l', 'l', ' ', 'p', 'i', 'c', 'k', ' ', 'y', 'o', 'u', ' ', 'u', 'p', '.', '\n', 'L', 'o', 'o', 'k', 'i', 'n', 'g', ' ', 's', 'h', 'a', 'r', 'p', '.', '\n', 'U', 's', 'e', ' ', 't', 'h', 'e', ' ', 's', 't', 'a', 'i', 'r', 's', ',', ' ', 'Y', 'o', 'u', 'r', ' ', 'f', 'a', 't', 'h', 'e', 'r', ' ', 'p', 'a', 'i', 'd', ' ', 'g', 'o', 'o', 'd', ' ', 'm', 'o', 'n', 'e', 'y', ' ', 'f', 'o', 'r', ' ', 't', 'h', 'o', 's', 'e', '.', '\n', 'S', 'o', 'r', 'r', 'y', '.', ' ', 'I', "'", 'm', ' ', 'e', 'x', 'c', 'i', 't', 'e', 'd', '.', '\n', 'H', 'e', 'r', 'e', "'", 's', ' ', 't', 'h', 'e', ' ', 'g', 'r', 'a', 'd', 'u', 'a', 't', 'e', '.', '\n', 'W', 'e', "'", 'r', 'e', ' ', 'v', 'e', 'r', 'y', ' ', 'p', 'r', 'o', 'u', 'd', ' ', 'o', 'f', ' ', 'y', 'o', 'u', ',', ' ', 's', 'o', 'n', '.', '\n', 'A', ' ', 'p', 'e', 'r', 'f', 'e', 'c', 't', ' ', 'r', 'e', 'p', 'o', 'r', 't', ' ', 'c', 'a', 'r', 'd', ',', ' ', 'a', 'l', 'l', ' ', 'B', "'", 's', '.', '\n', 'V', 'e', 'r', 'y', ' ', 'p', 'r', 'o', 'u', 'd', '.', '\n', 'M', 'a', '!', ' ', 'I', ' ', 'g', 'o', 't', ' ', 'a', ' ', 't', 'h', 'i', 'n', 'g', ' ', 'g', 'o', 'i', 'n', 'g', ' ', 'h', 'e', 'r', 'e', '.', '\n', 'Y', 'o', 'u', ' ', 'g', 'o', 't', ' ', 'l', 'i', 'n', 't', ' ', 'o', 'n', ' ', 'y', 'o', 'u', 'r', ' ', 'f', 'u', 'z', 'z', '.', '\n', 'O', 'w', '!', ' ', 'T', 'h', 'a', 't', "'", 's', ' ', 'm', 'e', '!', '\n', 'W', 'a', 'v', 'e', ' ', 't', 'o', ' ', 'u', 's', '!', ' ', 'W', 'e', "'", 'l', 'l', ' ', 'b', 'e', ' ', 'i', 'n', ' ', 'r', 'o', 'w', ' ', 'o', 'n', 'e', 'o', 'n', 'e', 'e', 'i', 'g', 'h', 't', ',', 'z', 'e', 'r', 'o', 'z', 'e', 'r', 'o', 'z', ...
